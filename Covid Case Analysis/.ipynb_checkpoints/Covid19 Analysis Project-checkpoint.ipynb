# %% [markdown]
# # Case Study : Covid Cases Data Analysis

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import the Dataset
dataset= pd.read_csv("covid19_Confirmed_dataset.csv")
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %%
#Parmanent Deleting the columns from the DataSet
df=dataset.drop(['Lat','Long'], axis=1, inplace=True)
dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
#see countrywise aggregate data
corona_Agg_dataset=dataset.groupby('Country/Region').sum()
corona_Agg_dataset.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# ...

# %%
# After Grouping
corona_Agg_dataset.shape
# Out:
# (187, 101)

# %%
#Visualise the Data
corona_Agg_dataset.loc["India"].plot()
corona_Agg_dataset.loc["Afghanistan"].plot()
corona_Agg_dataset.loc["US"].plot()
corona_Agg_dataset.loc["Japan"].plot()
plt.legend()

# %%
#last 5 days corona spread data
corona_Agg_dataset.loc["India"][-5:].plot()
# Out:
# <Axes: >

# %%
corona_Agg_dataset.loc["India"].diff().plot()
# Out:
# <Axes: >

# %%
# Max case reported
corona_Agg_dataset.loc["India"].diff().max()
# Out:
# 1893

# %%
# Max case reported
corona_Agg_dataset.loc["Spain"].diff().max()
# Out:
# 9630

# %%
countrys=list(corona_Agg_dataset.index)

df=pd.DataFrame(corona_Agg_dataset)
df = df.apply(pd.to_numeric, errors='coerce')
max_inf_rate= []

for c in countrys:
    max_inf_rate.append(df.loc[c].diff().max())
corona_Agg_dataset["Max_infection_Rate"]=max_inf_rate

# %%
corona_Agg_dataset
# Out:
#                    Province/State  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan                     0        0        0        0        0
# Albania                         0        0        0        0        0
# Algeria                         0        0        0        0        0
# Andorra                         0        0        0        0        0
# Angola                          0        0        0        0        0
# ...                           ...      ...      ...      ...      ...
# West Bank and Gaza              0        0        0        0        0
# Western Sahara                  0        0        0        0        0
# Yemen                           0        0        0        0        0
# Zambia                          0        0        0        0        0
# Zimbabwe                        0        0        0        0        0
#
#                     1/26/20  1/27/20  1/28/20  1/29/20  1/30/20  ...  4/22/20  \
# ...

# %%
corona_data=pd.DataFrame(corona_Agg_dataset["Max_infection_Rate"])
corona_data
# Out:
#                     Max_infection_Rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %%
#importing Dataset 2 ie World Happiness Report
happines_report=pd.read_csv("worldwide_happiness_report.csv")

# %%
happines_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#drop useless column

useless=['Overall rank','Score','Generosity','Perceptions of corruption']
happines_report.drop(useless,axis=1, inplace=True)
happines_report
# Out:
#             Country or region  GDP per capita  Social support  \
# 0                     Finland           1.340           1.587
# 1                     Denmark           1.383           1.573
# 2                      Norway           1.488           1.582
# 3                     Iceland           1.380           1.624
# 4                 Netherlands           1.396           1.522
# ..                        ...             ...             ...
# 151                    Rwanda           0.359           0.711
# 152                  Tanzania           0.476           0.885
# 153               Afghanistan           0.350           0.517
# 154  Central African Republic           0.026           0.000
# 155               South Sudan           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices
# 0                      0.986                         0.596
# 1                      0.996                         0.592
# ...

# %%
happines_report.set_index('Country or region',inplace=True)
happines_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happines_report.shape
# Out:
# (156, 4)

# %%
finalData=corona_data.join(happines_report, how="inner")
finalData
# Out:
#              Max_infection_Rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                  29.0           0.960           1.427
# Vietnam                    19.0           0.741           1.346
# Yemen                       5.0           0.287           1.163
# Zambia                      9.0           0.578           1.058
# Zimbabwe                    8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
finalData.corr()
# Out:
#                               Max_infection_Rate  GDP per capita  \
# Max_infection_Rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max_infection_Rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max_infection_Rate                                0.078196
# ...

# %%
x=finalData['GDP per capita']
y=finalData['Max_infection_Rate']
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_Rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_Rate'>

# %%
x=finalData['Healthy life expectancy']
y=finalData['Max_infection_Rate']
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_Rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_Rate'>

# %%
x=finalData['Freedom to make life choices']
y=finalData['Max_infection_Rate']
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_Rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_Rate'>
